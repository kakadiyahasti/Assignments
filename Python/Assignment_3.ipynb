# %% [markdown]
# 1.Declare four variables in Python: one integer (number of followers), one float (average rating), one string (your favorite app's name), and one boolean (is_premium_user). Print each variable and its type using the type() function.

# %%
number_of_followers = 200
average_rating = 4.5
fav_app = "Instagram"
is_premiun_uer = False

print(number_of_followers,type(number_of_followers))
print(average_rating,type(average_rating))
print(fav_app,type(fav_app))
print(is_premiun_uer,type(is_premiun_uer))
# Out:
# 200 <class 'int'>
# 4.5 <class 'float'>
# Instagram <class 'str'>
# False <class 'bool'>

# %% [markdown]
# Write a Python program that takes a user's input for the price of a Zomato order as a string, converts it to a float using type casting, adds 18% GST, and prints the final bill amount.

# %%
order_total = float(input("Enter your order total : "))
GST = .18
final_amount = order_total + (order_total * GST)
print(final_amount)
# Out:
# 525.1

# %% [markdown]
# Given a list of strings representing product prices from Flipkart, like ['199.99', '299.50', '150'], convert all to floats and calculate the total cart value

# %%
cart = ['199.99', '299.50', '150']

for i in range(len(cart)):
    cart[i] = float(cart[i])

print(cart)
total_cart_value = sum(cart)
print(total_cart_value)
# Out:
# [199.99, 299.5, 150.0]
# 649.49

# %% [markdown]
# Build a function is_discount_applicable(order_amount) that takes a float and returns True if the amount is greater than 500, otherwise False. Print the result for order amounts 450 and 750.

# %%
# order_amount = float(input("Enter order amount : "))

def is_discount_applicable(order_amount):
    # print(f"your order amount is :{order_amount} ")

    if float(order_amount) > 500 :
        return True
    else:
        return False
    
print(is_discount_applicable(450.50))
print(is_discount_applicable(750))
# Out:
# False
# True

# %% [markdown]
# You received a dataset of ratings as strings from Spotify: ['4.5', '3.0', '5', '4.2']. Use type casting to convert these to floats, then find and print the highest rating.<br><br><em><strong>Hint:</strong> Use the float() function inside a loop or list comprehension.</em>

# %%
Spotify_ratings = ['4.5','3.0','5','4.2']

for i in range(len(Spotify_ratings)):
    
    Spotify_ratings[i] = float(Spotify_ratings[i])
    
print(Spotify_ratings)
max_rating = max(Spotify_ratings)
print(f"Maximum rating : {max_rating} ")
# Out:
# [4.5, 3.0, 5.0, 4.2]
# Maximum rating : 5.0
