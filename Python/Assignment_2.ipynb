# %% [markdown]
# 1.
# Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.

# %%
user_name = "Hasti Kakadiya"
fav_app = "Instagram"
daily_usage_hours = 2

# %% [markdown]
# 2. Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function

# %%
product_name = "Pen"
price = 10.00
is_available = True

print('Product name =  ',product_name,",Data Type : ",type(product_name))
print('price = ',price,",Data Type : ",type(price))
print('is avilable = ',is_available,",Data Type : ",type(is_available))
# Out:
# Product name =   Pen ,Data Type :  <class 'str'>
# price =  10.0 ,Data Type :  <class 'float'>
# is avilable =  True ,Data Type :  <class 'bool'>

# %% [markdown]
# 3. Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. Use # for single-line and triple quotes for multi-line comments.

# %%
#single line comment


# A Spotify playlist recommendation system works by combining collaborative filtering, 
# content-based audio analysis, and user behavior tracking. It matches your listening 
# habits with millions of other users, analyzes the actual sound and metadata of tracks, 
# and ranks the best song choices for your personal taste.

# %%
'''
Multiline comment


A Spotify playlist recommendation system works by combining collaborative filtering, 
content-based audio analysis, and user behavior tracking. It matches your listening 
habits with millions of other users, analyzes the actual sound and metadata of tracks, 
and ranks the best song choices for your personal taste.'''
# Out:
# '\nMultiline comment\n\n\nA Spotify playlist recommendation system works by combining collaborative filtering, \ncontent-based audio analysis, and user behavior tracking. It matches your listening \nhabits with millions of other users, analyzes the actual sound and metadata of tracks, \nand ranks the best song choices for your personal taste.'

# %% [markdown]
# 4.Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. Follow Python naming conventions and print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

# %%
order_total = 500
delivery_region = "South"
discount_percent = 5

print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from South totals ₹500 with 5% discount.

# %% [markdown]
# Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>
