# %%
Name = "Hasti"
Favourite_App = "Instagram"

# %%
print("my name is ",Name,".My favourite app is ",Favourite_App)
# Out:
# my name is  Hasti .My favourite app is  Instagram

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 7, 31, 15, 11, 23, 784957)
